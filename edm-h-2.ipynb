# %% [markdown]
# # Students' Academic Performance Dataset
#
# ## Source of Data
#
# The source of this dataset is Kaggle. It has been downloaded from Kaggle from the following link.
#
# https://www.kaggle.com/aljarah/xAPI-Edu-Data

# %% [markdown]
# ##  Importing Packages

# %%
# Importing pandas, numpy and matplotlip

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import scipy.stats as stats
import math

# %% [markdown]
# ## Getting or reading CSV Data

# %%
df = pd.read_csv('xAPI-Edu-Data.csv')

# %% [markdown]
# ## Data Exploration and Understanding the Dataset
# In this stage, we will try to understand the dataset by checking what the dataset has as rows and columns.

# %% [markdown]
# ### Getting the shape of the dataframe

# %%
# Total number of oberservation or sample size and variables
# The data has 480 rows and 17 columns
df.shape
# Out:
# (480, 17)

# %%
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %% [markdown]
# ## Checking for Missing Data
# As shown from the result below, the dataset does not have a missing data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %% [markdown]
# ## Getting and udentifying the columns
# To know the variables of the data

# %%
columns = df.columns
columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %% [markdown]
# ## Getting the head and  tail of the data
# To get a very go understanding of the data

# %%
# Gives the first five records
df.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
# Exploring the first 25 rows
df.head(25)
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID Topic  \
# 0       M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 1       M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 2       M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 3       M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 4       M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 5       F          KW       KuwaIT    lowerlevel    G-04         A    IT
# 6       M          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 7       M          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 8       F          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 9       F          KW       KuwaIT  MiddleSchool    G-07         B    IT
# 10      M          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 11      M          KW       KuwaIT  MiddleSchool    G-07         B  Math
# ...

# %%
# To check last five records
df.tail()
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 475  Chemistry        S   Father            5                 4
# 476    Geology        F   Father           50                77
# 477    Geology        S   Father           55                74
# 478    History        F   Father           30                17
# 479    History        S   Father           35                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 475                  5           8                    No
# ...

# %% [markdown]
# ## Descriptive statistical Analysis

# %%
# Getting statistical description about the data

df.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   480.000000        480.000000         480.000000  480.000000
# mean     46.775000         54.797917          37.918750   43.283333
# std      30.779223         33.080007          26.611244   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      15.750000         20.000000          14.000000   20.000000
# 50%      50.000000         65.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %% [markdown]
# ##  Absence

# %%
def absence_graph ():
    absence_under_seven = df.loc[df['StudentAbsenceDays'] == 'Under-7']
    absence_above_seven = df.loc[df['StudentAbsenceDays'] == 'Above-7']

    fig = plt.figure()
    ax = fig.add_axes([0,0,1, 2])
    x = ['Above 7', 'Under 7']
    y = [len(absence_above_seven), len(absence_under_seven)]
    ax.bar(x, y)
    plt.show()
    
absence_graph()

# %%
low_level_students = df[df['StageID']=='lowerlevel']
low_level_students
# Out:
#     gender NationalITy PlaceofBirth     StageID GradeID SectionID   Topic  \
# 0        M          KW       KuwaIT  lowerlevel    G-04         A      IT
# 1        M          KW       KuwaIT  lowerlevel    G-04         A      IT
# 2        M          KW       KuwaIT  lowerlevel    G-04         A      IT
# 3        M          KW       KuwaIT  lowerlevel    G-04         A      IT
# 4        M          KW       KuwaIT  lowerlevel    G-04         A      IT
# ..     ...         ...          ...         ...     ...       ...     ...
# 385      F        Iraq         Iraq  lowerlevel    G-02         B  Arabic
# 386      M      Jordan       Jordan  lowerlevel    G-02         B  Arabic
# 387      M      Jordan       Jordan  lowerlevel    G-02         B  Arabic
# 388      M      Jordan  SaudiArabia  lowerlevel    G-02         B  Arabic
# 389      M      Jordan  SaudiArabia  lowerlevel    G-02         B  Arabic
#
#     Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# ...

# %% [markdown]
# ## Educational Stage

# %%
stages = df.groupby('StageID').count().iloc[:,1].sort_values()
x = stages.index
y = stages.values
fig = plt.figure()
ax = fig.add_axes([0,0,2, 2])
ax.bar(x, y)
ax.set_xlabel('Level')
ax.set_title('Educational Stages')
plt.show()

# %%
## Educational Topics

# %%
def topics_graph ():
    topics = df.groupby('Topic').count().iloc[:,1].sort_values()
    x = topics.index
    y = topics.values

    fig = plt.figure()
    ax = fig.add_axes([0,0,2, 2])
    ax.bar(x, y)
    ax.set_xlabel('Topics')
    ax.set_ylabel('Number of students')
    ax.set_title('Educational Topics')
    plt.show()
topics_graph()

# %%
df['NationalITy'].describe()
# Out:
# count     480
# unique     14
# top        KW
# freq      179
# Name: NationalITy, dtype: object

# %%
df.groupby('NationalITy').count()
# Out:
#              gender  PlaceofBirth  StageID  GradeID  SectionID  Topic  \
# NationalITy
# Egypt             9             9        9        9          9      9
# Iran              6             6        6        6          6      6
# Iraq             22            22       22       22         22     22
# Jordan          172           172      172      172        172    172
# KW              179           179      179      179        179    179
# Lybia             6             6        6        6          6      6
# Morocco           4             4        4        4          4      4
# Palestine        28            28       28       28         28     28
# SaudiArabia      11            11       11       11         11     11
# Syria             7             7        7        7          7      7
# Tunis            12            12       12       12         12     12
# USA               6             6        6        6          6      6
# ...

# %%
 nationality = df.groupby('NationalITy').count().iloc[:,1].sort_values()
 nationality
# Out:
# NationalITy
# venzuela         1
# Morocco          4
# Iran             6
# Lybia            6
# USA              6
# Syria            7
# Egypt            9
# SaudiArabia     11
# Tunis           12
# lebanon         17
# Iraq            22
# Palestine       28
# Jordan         172
# KW             179
# Name: PlaceofBirth, dtype: int64

# %%
countries = list(nationality.index)
print(countries)
students = list(nationality.values)
print(students)
# Out:
# ['venzuela', 'Morocco', 'Iran', 'Lybia', 'USA', 'Syria', 'Egypt', 'SaudiArabia', 'Tunis', 'lebanon', 'Iraq', 'Palestine', 'Jordan', 'KW']
# [1, 4, 6, 6, 6, 7, 9, 11, 12, 17, 22, 28, 172, 179]

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,2,2])
ax.bar(countries[::-1],students[::-1])
plt.show()

# %%
df_male = df.loc[df['gender'] == 'M']
print(len(df_male))

df_female = df.loc[df['gender'] == 'F']
print(len(df_female))
# Out:
# 305
# 175

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1, 2])
x = ['Male', 'Female']
y = [len(df_male), len(df_female)]
ax.bar(x, y)
plt.show()

# %%
labels = ['Male','Female']
sizes= [len(df_male), len(df_female)]
fig1, ax1 = plt.subplots()

fig1.set_size_inches(8,8)
ax1.pie(sizes,labels=labels, autopct='%1.1f%%')
ax1.set_title('Male vs Female')
ax1.axis('equal')
plt.show()

# %%
df_female
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 5        F          KW       KuwaIT    lowerlevel    G-04         A
# 8        F          KW       KuwaIT  MiddleSchool    G-07         A
# 9        F          KW       KuwaIT  MiddleSchool    G-07         B
# 14       F          KW       KuwaIT  MiddleSchool    G-08         A
# 15       F          KW       KuwaIT  MiddleSchool    G-06         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 5           IT        F   Father           42                30
# ...

# %%
print('Female students ')
female_nationality = df_female.groupby('NationalITy').count().iloc[:,1]
print(female_nationality)
female_students = list(female_nationality.values)
female_students_countries = list( female_nationality.index)
print(female_students_countries)
print(female_students)

print('Male student')
male_nationality = df_male.groupby('NationalITy').count().iloc[:,1]
print(male_nationality)
male_students = list(male_nationality.values)
male_students_countries = list( male_nationality.index)
print(male_students_countries)
print(male_students)
print(len(female_students_countries) == len(male_students_countries))
# Out:
# Female students
# NationalITy
# Egypt           2
# Iran            1
# Iraq            6
# Jordan         79
# KW             54
# Lybia           2
# Morocco         1
# Palestine       8
# SaudiArabia     4
# Syria           2
# Tunis           1
# USA             4
# lebanon        11
# Name: PlaceofBirth, dtype: int64
# ['Egypt', 'Iran', 'Iraq', 'Jordan', 'KW', 'Lybia', 'Morocco', 'Palestine', 'SaudiArabia', 'Syria', 'Tunis', 'USA', 'lebanon']
# [2, 1, 6, 79, 54, 2, 1, 8, 4, 2, 1, 4, 11]
# Male student
# NationalITy
# Egypt            7
# Iran             5
# Iraq            16
# Jordan          93
# KW             125
# Lybia            4
# Morocco          3
# Palestine       20
# SaudiArabia      7
# Syria            5
# Tunis           11
# USA              2
# lebanon          6
# venzuela         1
# Name: PlaceofBirth, dtype: int64
# ['Egypt', 'Iran', 'Iraq', 'Jordan', 'KW', 'Lybia', 'Morocco', 'Palestine', 'SaudiArabia', 'Syria', 'Tunis', 'USA', 'lebanon', 'venzuela']
# ...

# %%
fig = plt.figure()
data = [female_students, male_students]
ax = fig.add_axes([0,0,2,2])

ax.bar(male_students_countries,male_students)
ax.bar(female_students_countries, female_students)

ax.legend(labels=['Male', 'Female'])
ax.set_xlabel('Countries')
ax.set_ylabel('Number of students')
ax.set_title('Number of male and female students by country')

plt.show()

# %%
df_female.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   175.000000        175.000000         175.000000  175.000000
# mean     52.862857         64.000000          39.748571   47.828571
# std      30.218049         30.209803          25.638842   28.900429
# min       0.000000          0.000000           0.000000    1.000000
# 25%      24.000000         40.000000          19.500000   21.500000
# 50%      60.000000         79.000000          36.000000   43.000000
# 75%      79.000000         88.000000          55.000000   72.500000
# max     100.000000         99.000000          98.000000   98.000000

# %%
df_female.corr()
# Out:
#                    raisedhands  VisITedResources  AnnouncementsView  \
# raisedhands           1.000000          0.627500           0.580731
# VisITedResources      0.627500          1.000000           0.446811
# AnnouncementsView     0.580731          0.446811           1.000000
# Discussion            0.159834         -0.101254           0.373844
#
#                    Discussion
# raisedhands          0.159834
# VisITedResources    -0.101254
# AnnouncementsView    0.373844
# Discussion           1.000000

# %%
df_male.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   305.000000        305.000000         305.000000  305.000000
# mean     43.281967         49.518033          36.868852   40.675410
# std      30.602167         33.543185          27.139185   26.585319
# min       0.000000          0.000000           0.000000    1.000000
# 25%      15.000000         14.000000          12.000000   19.000000
# 50%      39.000000         52.000000          32.000000   34.000000
# 75%      72.000000         82.000000          59.000000   61.000000
# max     100.000000         98.000000          98.000000   99.000000

# %%
df_male.corr()
# Out:
#                    raisedhands  VisITedResources  AnnouncementsView  \
# raisedhands           1.000000          0.712000           0.678386
# VisITedResources      0.712000          1.000000           0.671473
# AnnouncementsView     0.678386          0.671473           1.000000
# Discussion            0.430126          0.407266           0.440044
#
#                    Discussion
# raisedhands          0.430126
# VisITedResources     0.407266
# AnnouncementsView    0.440044
# Discussion           1.000000

# %% [markdown]
# # Correlation among different variables

# %%
df.corr()
# Out:
#                    raisedhands  VisITedResources  AnnouncementsView  \
# raisedhands           1.000000          0.691572           0.643918
# VisITedResources      0.691572          1.000000           0.594500
# AnnouncementsView     0.643918          0.594500           1.000000
# Discussion            0.339386          0.243292           0.417290
#
#                    Discussion
# raisedhands          0.339386
# VisITedResources     0.243292
# AnnouncementsView    0.417290
# Discussion           1.000000
